# %%
### imports
import requests
import io
import pandas as pd
import re

from bs4 import BeautifulSoup as bs

# %%
### config
URL = "https://realpython.github.io/fake-jobs/"

# %%
### request url and let bs work
response = requests.get(URL)
soup = bs(response.text)

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fake Python
#   </title>
#   <link href="https://cdn.jsdelivr.net/npm/bulma@0.9.2/css/bulma.min.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <section class="section">
#    <div class="container mb-5">
#     <h1 class="title is-1">
#      Fake Python
#     </h1>
#     <p class="subtitle is-3">
#      Fake Jobs for Your Web Scraping Journey
#     </p>
#    </div>
#    <div class="container">
#     <div class="columns is-multiline" id="ResultsContainer">
#      <div class="column is-half">
#       <div class="card">
#        <div class="card-content">
#         <div class="media">
#          <div class="media-left">
#           <figure class="image is-48x48">
#            <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
#           </figure>
# ...

# %%
### bs can target specific tags
title = soup.find('title')
title.text
# Out:
# 'Fake Python'

# %%
### like fetching all the images
images = soup.find_all('img')
images
# Out:
# [<img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
#  <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>,
# ...

# %%
### take a look at a single image
sample_img = images[0]
sample_img
# Out:
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>

# %%
### pick out specfic tags within the first. can use .get() to account for tags that may not exist
print(sample_img.get('alt', "no alt"))
print(sample_img.get('src', "no src"))
print(sample_img.get('notRealTag', "no tag"))
# Out:
# Real Python Logo
# https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1
# no tag

# %%
### we can run through specific tags and add them to a list
### like if we want src from all images
image_src = [x.get('src') for x in images]
image_src
# Out:
# ['https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
#  'https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1',
# ...

# %% [markdown]
# # Webscraping ______________________

# %%
### use .find to pull first job title
### <h2 class="title is-5">Senior Python Developer</h2>
x = soup.find_all('h2')
x[0].text
# Out:
# 'Senior Python Developer'

# %%
### use .find_all to get all h2 - for loop to insert .text into job_titles[]
job_titles = soup.find_all('h2')
job_titles = [x.text for x in job_titles]
job_titles
# Out:
# ['Senior Python Developer',
#  'Energy engineer',
#  'Legal executive',
#  'Fitness centre manager',
#  'Product manager',
#  'Medical technical officer',
#  'Physiological scientist',
#  'Textile designer',
#  'Television floor manager',
#  'Waste management officer',
#  'Software Engineer (Python)',
#  'Interpreter',
#  'Architect',
#  'Meteorologist',
#  'Audiological scientist',
#  'English as a second language teacher',
#  'Surgeon',
#  'Equities trader',
#  'Newspaper journalist',
#  'Materials engineer',
#  'Python Programmer (Entry-Level)',
#  'Product/process development scientist',
#  'Scientist, research (maths)',
#  'Ecologist',
#  'Materials engineer',
#  'Historic buildings inspector/conservation officer',
#  'Data scientist',
#  'Psychiatrist',
#  'Structural engineer',
#  'Immigration officer',
#  'Python Programmer (Entry-Level)',
#  'Neurosurgeon',
#  'Broadcast engineer',
#  'Make',
#  'Nurse, adult',
#  'Air broker',
#  'Editor, film/video',
# ...

# %%
### use .find_all to get all h3 - for loop to insert .text into companies[]
companies = soup.find_all('h3')
companies = [x.text for x in companies]
companies
# Out:
# ['Payne, Roberts and Davis',
#  'Vasquez-Davidson',
#  'Jackson, Chambers and Levy',
#  'Savage-Bradley',
#  'Ramirez Inc',
#  'Rogers-Yates',
#  'Kramer-Klein',
#  'Meyers-Johnson',
#  'Hughes-Williams',
#  'Jones, Williams and Villa',
#  'Garcia PLC',
#  'Gregory and Sons',
#  'Clark, Garcia and Sosa',
#  'Bush PLC',
#  'Salazar-Meyers',
#  'Parker, Murphy and Brooks',
#  'Cruz-Brown',
#  'Macdonald-Ferguson',
#  'Williams, Peterson and Rojas',
#  'Smith and Sons',
#  'Moss, Duncan and Allen',
#  'Gomez-Carroll',
#  'Manning, Welch and Herring',
#  'Lee, Gutierrez and Brown',
#  'Davis, Serrano and Cook',
#  'Smith LLC',
#  'Thomas Group',
#  'Silva-King',
#  'Pierce-Long',
#  'Walker-Simpson',
#  'Cooper and Sons',
#  'Donovan, Gonzalez and Figueroa',
#  'Morgan, Butler and Bennett',
#  'Snyder-Lee',
#  'Harris PLC',
#  'Washington PLC',
#  'Brown, Price and Campbell',
#  'Mcgee PLC',
#  'Dixon Inc',
#  'Thompson, Sheppard and Ward',
#  'Adams-Brewer',
#  'Schneider-Brady',
# ...

# %%
### use .find_all('p', class_='location') to get all <p> tags with specific class tab assoc.
### make for loop to insert .text into loactions[] striping away \n and spaces
locations = soup.find_all('p', class_='location')
locations = [x.text.strip('\n').strip(' ').strip('\n') for x in locations]
locations
# Out:
# ['Stewartbury, AA',
#  'Christopherville, AA',
#  'Port Ericaburgh, AA',
#  'East Seanview, AP',
#  'North Jamieview, AP',
#  'Davidville, AP',
#  'South Christopher, AE',
#  'Port Jonathan, AE',
#  'Osbornetown, AE',
#  'Scotttown, AP',
#  'Ericberg, AE',
#  'Ramireztown, AE',
#  'Figueroaview, AA',
#  'Kelseystad, AA',
#  'Williamsburgh, AE',
#  'Mitchellburgh, AE',
#  'West Jessicabury, AA',
#  'Maloneshire, AE',
#  'Johnsonton, AA',
#  'South Davidtown, AP',
#  'Port Sara, AE',
#  'Marktown, AA',
#  'Laurenland, AE',
#  'Lauraton, AP',
#  'South Tammyberg, AP',
#  'North Brandonville, AP',
#  'Port Robertfurt, AA',
#  'Burnettbury, AE',
#  'Herbertside, AA',
#  'Christopherport, AP',
#  'West Victor, AE',
#  'Port Aaron, AP',
#  'Loribury, AA',
#  'Angelastad, AP',
#  'Larrytown, AE',
#  'West Colin, AP',
#  'West Stephanie, AP',
#  'Laurentown, AP',
#  'Wrightberg, AP',
#  'Alberttown, AE',
#  'Brockburgh, AE',
#  'North Jason, AE',
#  'Arnoldhaven, AE',
#  'Lake Destiny, AP',
# ...

# %%
### use .find_all <time> tags - for loop to insert .text into posting_date[]
posting_date = soup.find_all('time')
posting_date = [x.text for x in posting_date]
posting_date
# Out:
# ['2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
# ...

# %%
### create DataFrame from all the scraped lists we have
jobs_df = pd.DataFrame({
    "Job Title": job_titles,
    "Company": companies,
    "Location": locations,
    "Posting Date": posting_date
})

# %%
### populate the apply url column using regex, strip(), and str cat to prep our url
apply_url = jobs_df['Job Title'].loc[0]
base_url = "https://realpython.github.io/fake-jobs/jobs/"

for x in range(0, len(jobs_df)):
    ### the use of .loc[] here is being removed from pandas so we have to use the next line
    #jobs_df['Job Title'].loc[x] = base_url + (re.sub(r'[^a-z0-9]+', '-', jobs_df['Job Title'].loc[x].lower()) + str(x))
    jobs_df.loc[x, 'Apply url'] = base_url + (re.sub(r'[^a-z0-9]+', '-', jobs_df.loc[x, 'Job Title'].lower()).rstrip('-') + '-' + str(x))
    
    print(jobs_df['Apply url'].loc[x])
# Out:
# https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0
# https://realpython.github.io/fake-jobs/jobs/energy-engineer-1
# https://realpython.github.io/fake-jobs/jobs/legal-executive-2
# https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3
# https://realpython.github.io/fake-jobs/jobs/product-manager-4
# https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5
# https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6
# https://realpython.github.io/fake-jobs/jobs/textile-designer-7
# https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8
# https://realpython.github.io/fake-jobs/jobs/waste-management-officer-9
# https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10
# https://realpython.github.io/fake-jobs/jobs/interpreter-11
# https://realpython.github.io/fake-jobs/jobs/architect-12
# https://realpython.github.io/fake-jobs/jobs/meteorologist-13
# ...

# %%
### define function to return job desc from related webpage and use .apply()
def get_desc(url):
    response = requests.get(url)
    soup = bs(response.text)
    content = soup.find_all('p')
    return content[1].text.strip()

jobs_df['Job Desc'] = jobs_df['Apply url'].apply(get_desc)
jobs_df
# Out:
#                              Job Title                     Company  \
# 0              Senior Python Developer    Payne, Roberts and Davis
# 1                      Energy engineer            Vasquez-Davidson
# 2                      Legal executive  Jackson, Chambers and Levy
# 3               Fitness centre manager              Savage-Bradley
# 4                      Product manager                 Ramirez Inc
# ..                                 ...                         ...
# 95  Museum/gallery exhibitions officer     Nguyen, Yoder and Petty
# 96            Radiographer, diagnostic                  Holder LLC
# 97              Database administrator              Yates-Ferguson
# 98                  Furniture designer             Ortega-Lawrence
# 99                         Ship broker   Fuentes, Walls and Castro
#
#                 Location Posting Date  \
# 0        Stewartbury, AA   2021-04-08
# 1   Christopherville, AA   2021-04-08
# 2    Port Ericaburgh, AA   2021-04-08
# ...

# %%
### this version still uses the above function but inserts the desc row by row with for loop
for x in range(0, len(jobs_df)):
    #jobs_df['Job Title'].loc[x] = base_url + (re.sub(r'[^a-z0-9]+', '-', jobs_df['Job Title'].loc[x].lower()) + str(x))
    jobs_df.loc[x, 'Job Desc'] = get_desc(jobs_df.loc[x, 'Apply url'])

jobs_df
# Out:
#                              Job Title                     Company  \
# 0              Senior Python Developer    Payne, Roberts and Davis
# 1                      Energy engineer            Vasquez-Davidson
# 2                      Legal executive  Jackson, Chambers and Levy
# 3               Fitness centre manager              Savage-Bradley
# 4                      Product manager                 Ramirez Inc
# ..                                 ...                         ...
# 95  Museum/gallery exhibitions officer     Nguyen, Yoder and Petty
# 96            Radiographer, diagnostic                  Holder LLC
# 97              Database administrator              Yates-Ferguson
# 98                  Furniture designer             Ortega-Lawrence
# 99                         Ship broker   Fuentes, Walls and Castro
#
#                 Location Posting Date  \
# 0        Stewartbury, AA   2021-04-08
# 1   Christopherville, AA   2021-04-08
# 2    Port Ericaburgh, AA   2021-04-08
# ...
